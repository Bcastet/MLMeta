# %%
import leaguepedia
import arrow
from datetime import datetime
date = arrow.get('2022-01-01T00:00:00.000000+00:00')
scouted_leagues =  ["LEC/", "LCK/", "2021 Season World Championship/Main Event", "LFL"]
games = leaguepedia.requestScoutedLeaguesGames(date, scouted_leagues)
# Out:
# 2022-01-01T00:00:00+00:00
# SG.DateTime_UTC>'2022-01- 00:00:00' AND ((SG.OverviewPage LIKE '%LEC/%') OR (SG.OverviewPage LIKE '%LCK/%') OR (SG.OverviewPage LIKE '%2021 Season World Championship/Main Event%') OR (SG.OverviewPage LIKE '%LFL%'))
# OrderedDict([('cargoquery', [OrderedDict([('title', OrderedDict([('MatchHistory', 'http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2692441?gameHash=b4d2a07d5fc70e47'), ('Team1Ban1', 'LeBlanc'), ('Team1Ban2', 'Caitlyn'), ('Team1Ban3', 'Xin Zhao'), ('Team1Ban4', 'Rakan'), ('Team1Ban5', 'Pyke'), ('Team2Ban1', 'Twisted Fate'), ('Team2Ban2', 'Lee Sin'), ('Team2Ban3', 'Diana'), ('Team2Ban4', 'Wukong'), ('Team2Ban5', 'Malphite'), ('Team1Pick1', 'Thresh'), ('Team1Pick2', 'Jinx'), ('Team1Pick3', 'Jarvan IV'), ('Team1Pick4', 'Ornn'), ('Team1Pick5', 'Corki'), ('Team2Pick1', 'Jhin'), ('Team2Pick2', 'Viego'), ('Team2Pick3', 'Akshan'), ('Team2Pick4', 'Yuumi'), ('Team2Pick5', 'Kassadin'), ('Team1', 'MAD Lions'), ('Team2', 'G2 Esports'), ('Winner', '1'), ('Team1PicksByRoleOrder', 'Ornn,Jarvan IV,Corki,Jinx,Thresh'), ('Team2PicksByRoleOrder', 'Akshan,Viego,Kassadin,Jhin,Yuumi'), ('Blue', 'MAD Lions'), ('GameId', 'LEC/2022 Season/Spring Season_Week 1_15_1'), ('Patch', '12.1'), ('Red', 'G2 Esports'), ('DateTime UTC', '2022-01-16 19:38:00'), ('DateTime UTC__precision', '0')]))]), OrderedDict([('title', OrderedDict([('MatchHistory', 'http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2692425?gameHash=d3476d25ea023762'), ('Team1Ban1', 'Twisted Fate'), ('Team1Ban2', 'LeBlanc'), ('Team1Ban3', 'Caitlyn'), ('Team1Ban4', 'Ryze'), ('Team1Ban5', 'Gwen'), ('Team2Ban1', 'Diana'), ('Team2Ban2', 'Corki'), ('Team2Ban3', 'Jarvan IV'), ('Team2Ban4', 'Jhin'), ('Team2Ban5', 'Kalista'), ('Team1Pick1', 'Xin Zhao'), ('Team1Pick2', 'Gragas'), ('Team1Pick3', 'Rakan'), ('Team1Pick4', 'Ezreal'), ('Team1Pick5', 'Zoe'), ('Team2Pick1', 'Thresh'), ('Team2Pick2', 'Aphelios'), ('Team2Pick3', 'Lee Sin'), ('Team2Pick4', 'Viktor'), ('Team2Pick5', 'Gangplank'), ('Team1', 'SK Gaming'), ('Team2', 'Fnatic'), ('Winner', '2'), ('Team1PicksByRoleOrder', 'Gragas,Xin Zhao,Zoe,Ezreal,Rakan'), ('Team2PicksByRoleOrder', 'Gangplank,Lee Sin,Viktor,Aphelios,Thresh'), ('Blue', 'SK Gaming'), ('GameId', 'LEC/2022 Season/Spring Season_Week 1_14_1'), ('Patch', '12.1'), ('Red', 'Fnatic'), ('DateTime UTC', '2022-01-16 18:43:00'), ('DateTime UTC__precision', '0')]))]), OrderedDict([('title', OrderedDict([('MatchHistory', 'http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2692407?gameHash=f8d517ab4785c867'), ('Team1Ban1', 'Corki'), ('Team1Ban2', 'Lucian'), ('Team1Ban3', 'Vex'), ('Team1Ban4', 'Jarvan IV'), ('Team1Ban5', 'Malphite'), ('Team2Ban1', 'Twisted Fate'), ('Team2Ban2', 'LeBlanc'), ('Team2Ban3', 'Caitlyn'), ('Team2Ban4', 'Thresh'), ('Team2Ban5', 'Lee Sin'), ('Team1Pick1', 'Jinx'), ('Team1Pick2', 'Viktor'), ('Team1Pick3', 'Jayce'), ('Team1Pick4', 'Trundle'), ('Team1Pick5', 'Rakan'), ('Team2Pick1', 'Jhin'), ('Team2Pick2', 'Leona'), ('Team2Pick3', 'Akali'), ('Team2Pick4', 'Renekton'), ('Team2Pick5', 'Viego'), ('Team1', 'Rogue (European Team)'), ('Team2', 'Astralis'), ('Winner', '1'), ('Team1PicksByRoleOrder', 'Jayce,Trundle,Viktor,Jinx,Rakan'), ('Team2PicksByRoleOrder', 'Renekton,Viego,Akali,Jhin,Leona'), ('Blue', 'Rogue (European Team)'), ('GameId', 'LEC/2022 Season/Spring Season_Week 1_13_1'), ('Patch', '12.1'), ('Red', 'Astralis'), ('DateTime UTC', '2022-01-16 17:52:00'), ('DateTime UTC__precision', '0')]))]), OrderedDict([('title', OrderedDict([('MatchHistory', 'http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2702451?gameHash=1e1c60ffa29f6aa1'), ('Team1Ban1', 'Diana'), ('Team1Ban2', 'Yuumi'), ('Team1Ban3', 'Renekton'), ('Team1Ban4', 'Malphite'), ('Team1Ban5', 'Gangplank'), ('Team2Ban1', 'Twisted Fate'), ('Team2Ban2', 'Lee Sin'), ('Team2Ban3', 'Caitlyn'), ('Team2Ban4', 'Jhin'), ('Team2Ban5', 'Corki'), ('Team1Pick1', 'Xin Zhao'), ('Team1Pick2', 'Jayce'), ('Team1Pick3', 'Rakan'), ('Team1Pick4', 'LeBlanc'), ('Team1Pick5', 'Xayah'), ('Team2Pick1', 'Jinx'), ('Team2Pick2', 'Viego'), ('Team2Pick3', 'Thresh'), ('Team2Pick4', 'Wukong'), ('Team2Pick5', 'Vex'), ('Team1', 'Excel Esports'), ('Team2', 'Team Vi ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\pythonenv\lib\site-packages\merakicommons\cache.py in wrapper(self)
#      14         try:
# ---> 15             return getattr(self, s)
#      16         except AttributeError:
#
# AttributeError: 'Match' object has no attribute '_lazy__timeline'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# d:\pythonenv\lib\site-packages\merakicommons\cache.py in wrapper(self)
#      14         try:
# ---> 15             return getattr(self, s)
#      16         except AttributeError:
#
# AttributeError: 'Match' object has no attribute '_lazy__platform'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10916/4133692584.py in <module>
#       4 date = arrow.get('2022-01-01T00:00:00.000000+00:00')
#       5 scouted_leagues =  ["LEC/", "LCK/", "2021 Season World Championship/Main Event", "LFL"]
# ----> 6 games = leaguepedia.requestScoutedLeaguesGames(date, scouted_leagues)
#       7
#       8
#
# ~\PycharmProjects\lolmetagame\leaguepedia.py in requestScoutedLeaguesGames(date, scoutedLeagues)
#      60     print(response)
#      61     for match in response['cargoquery']:
# ---> 62         match["title"]["MatchHistory"] = get_cassmatch(match["title"]["MatchHistory"])
#      63
#      64     print(response['cargoquery'][0])
#
# ~\PycharmProjects\lolmetagame\leaguepedia.py in get_cassmatch(url)
#      34     cassmatch = cassiopeia.core.Match.from_data(match)
#      35     timelineClean = cassiopeia.core.match.Timeline.from_data(timelineData)
# ---> 36     cassmatch.timeline.from_data(timelineClean)
#      37     cassmatch.comp_timeline = timelineClean
#      38     print(cassmatch)
#
# d:\pythonenv\lib\site-packages\merakicommons\cache.py in wrapper(self)
#      15             return getattr(self, s)
#      16         except AttributeError:
# ---> 17             value = method(self)
#      18             setattr(self, s, value)
#      19             return value
#
# d:\pythonenv\lib\site-packages\cassiopeia\core\match.py in timeline(self)
#    1674     def timeline(self) -> Timeline:
#    1675         if self._timeline is None:
# -> 1676             gameId = self.platform.value + "_" + str(self.id)
#    1677             self._timeline = Timeline(id=gameId, continent=self.continent)
#    1678         return self._timeline
#
# d:\pythonenv\lib\site-packages\merakicommons\ghost.py in __get__(self, obj, obj_type)
#      85
#      86             try:
# ---> 87                 return self.fget(obj)
#      88             except GhostLoadingRequiredError:
#      89                 load_group = self.fget._Ghost__load_group
#
# d:\pythonenv\lib\site-packages\merakicommons\ghost.py in wrapper(*args, **kwargs)
#      39         def wrapper(*args, **kwargs):
#      40             try:
# ---> 41                 return method(*args, **kwargs)
#      42             except errors as error:
#      43                 raise GhostLoadingRequiredError(str(error))
#
# d:\pythonenv\lib\site-packages\merakicommons\cache.py in wrapper(self)
#      15             return getattr(self, s)
#      16         except AttributeError:
# ---> 17             value = method(self)
#      18             setattr(self, s, value)
#      19             return value
#
# d:\pythonenv\lib\site-packages\cassiopeia\core\match.py in platform(self)
#    1665     def platform(self) -> Platform:
#    1666         """The platform for this match."""
# -> 1667         return Platform(self._data[MatchData].platformId)
#    1668
#    1669     @property
#
# d:\pythonenv\lib\enum.py in __call__(cls, value, names, module, qualname, type, start)
#     337         """
#     338         if names is None:  # simple value lookup
# --> 339             return cls.__new__(cls, value)
#     340         # otherwise, functional API: we're creating a new Enum type
#     341         return cls._create_(
#
# d:\pythonenv\lib\enum.py in __new__(cls, value)
#     660             ve_exc = ValueError("%r is not a valid %s" % (value, cls.__name__))
#     661             if result is None and exc is None:
# --> 662                 raise ve_exc
#     663             elif exc is None:
#     664                 exc = TypeError(
#
# ValueError: 'ESPORTSTMNT01' is not a valid Platform
